# %%
import apache_beam as beam
import os
import json
import importlib
import unittest
import numpy as np

from datetime import datetime
from apache_beam.transforms.util import WaitOn
from apache_beam.options.pipeline_options import PipelineOptions
from pyspark.sql.functions import date_format, col
from pyspark.sql.types import TimestampType
# Out:
# Failed to import GCSFileSystem; loading of this filesystem will be skipped. Error details: cannot import name 'storage' from 'google.cloud' (unknown location)
# WARNING:root:crcmod package not found. This package is required if python-snappy or google-crc32c are not installed. To ensure crcmod is installed, install the tfrecord extra: pip install apache-beam[tfrecord]

# %%
fromNotebook = True
configFile = "load_wwi.json"
newCutoffDate = "2013-01-01"
tables = []
sqlUtilFilePath = "../modules/sql_utilities.py"
script_directory = ""
archivePath = os.getcwd()
is_rollback = False
release_github_repo = ""
release_github_branch = ""

# %%
print(f"sql_util_file_path: {sqlUtilFilePath}")

spec = importlib.util.spec_from_file_location("sql_utils", sqlUtilFilePath)
sql_utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(sql_utils)
# Out:
# sql_util_file_path: ../modules/sql_utilities.py

# %%
f = open(configFile,)
config = json.load(f)
f.close()

source_db = config["source"]
destination_db = config["destination"]
initialCutoffDate = config["initialCutoffDate"]
spark_master = config["sparkMaster"]
spark_jars = config["sparkJars"]
spark_executor_memory = config["sparkExecutorMemory"]
spark_driver_memory = config["sparkDriverMemory"]
spark_executor_cores = config["sparkExecutorCores"]
spark_cores_max = config["sparkCoresMax"]
spark_network_timeout = config["sparkNetworkTimeout"]
spark_executor_heartbeat_interval = config["sparkExecutorHeartBeatInterval"]
if fromNotebook == True:
    tables = config["tables"]
    newCutoffDate = config["cutoffDate"]
    is_rollback = config["isRollback"]
# elif is_rollback == True:
#     tables = config["tables"]
runner_options = config["runnerOptions"][config["runner"]]
gcpCredential = config["gcpCredential"]

print(f"tables: {tables}")
print(f"source_db: {source_db}")
print(f"destination_db: {destination_db}") 
print(f"initialCutoffDate: {initialCutoffDate}")
print(f"spark_master: {spark_master}")
print(f"spark_jars: {spark_jars}")
print(f"spark_executor_memory: {spark_executor_memory}")
print(f"spark_driver_memory: {spark_driver_memory}")
print(f"spark_executor_cores: {spark_executor_cores}")
print(f"spark_cores_max: {spark_cores_max}")
print(f"spark_network_timeout: {spark_network_timeout}")
print(f"spark_executor_heartbeat_interval: {spark_executor_heartbeat_interval}")
print(f"newCutoffDate: {newCutoffDate}")
print(f"runner_options: {runner_options}")
print(f"gcp_credential: {gcpCredential}")
print(f"is_rollback: {is_rollback}")
print(f"release_github_repo: {release_github_repo}")
print(f"release_github_branch: {release_github_branch}")

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = gcpCredential
# Out:
# tables: [{'name': 'ApplicationCities', 'source': {'schema': 'Application', 'table': 'Cities', 'loadTable': 'scripts/load_wwi_mssql/load_application_cities_2013-01-01.sql', 'fetchNumRecords': 'scripts/load_wwi_mssql/fetch_num_records.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}, 'destination': {'schema': 'dbo', 'table': 'Application_Cities', 'stagingTable': 'Application_Cities_Staging', 'createTable': 'scripts/load_wwi_mssql/create_application_cities_2013-01-01.sql', 'modifyTable': [], 'insertTable': 'scripts/load_wwi_mssql/insert_record.sql', 'dropTable': 'scripts/load_wwi_mssql/drop_table.sql', 'dropColumn': 'scripts/load_wwi_mssql/drop_column.sql', 'deleteByLastLoadDateTable': 'scripts/load_wwi_mssql/delete_record_by_last_load_date.sql', 'specificColumnTypes': [{'name': 'Location', 'type': 'VARBINARY(MAX)', 'typeCast': 'CAST(? AS VARBINARY(MAX))'}], 'testLoadTable': 'scripts/load_wwi_mssql/tests/load_application_cities_2013-01-01.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}}, {'name': 'ApplicationCitiesArchive', 'source': {'schema': 'Application', 'table': 'Cities_Archive', 'loadTable': 'scripts/load_wwi_mssql/load_application_cities_2013-01-01.sql', 'fetchNumRecords': 'scripts/load_wwi_mssql/fetch_num_records.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}, 'destination': {'schema': 'dbo', 'table': 'Application_Cities_Archive', 'stagingTable': 'Application_Cities_Archive_Staging', 'createTable': 'scripts/load_wwi_mssql/create_application_cities_2013-01-01.sql', 'modifyTable': [], 'insertTable': 'scripts/load_wwi_mssql/insert_record.sql', 'dropTable': 'scripts/load_wwi_mssql/drop_table.sql', 'dropColumn': 'scripts/load_wwi_mssql/drop_column.sql', 'deleteByLastLoadDateTable': 'scripts/load_wwi_mssql/delete_record_by_last_load_date.sql', 'specificColumnTypes': [{'name': 'Location', 'type': 'VARBINARY(MAX)', 'typeCast': 'CAST(? AS VARBINARY(MAX))'}], 'testLoadTable': 'scripts/load_wwi_mssql/tests/load_application_cities_2013-01-01.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}}, {'name': 'ApplicationCountries', 'source': {'schema': 'Application', 'table': 'Countries', 'loadTable': 'scripts/load_wwi_mssql/load_application_countries.sql', 'fetchNumRecords': 'scripts/load_wwi_mssql/fetch_num_records.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}, 'destination': {'schema': 'dbo', 'table': 'Application_Countries', 'stagingTable': 'Application_Countries_Staging', 'createTable': 'scripts/load_wwi_mssql/create_application_countries.sql', 'modifyTable': [], 'insertTable': 'scripts/load_wwi_mssql/insert_record.sql', 'dropTable': 'scripts/load_wwi_mssql/drop_table.sql', 'dropColumn': 'scripts/load_wwi_mssql/drop_column.sql', 'deleteByLastLoadDateTable': 'scripts/load_wwi_mssql/delete_record_by_last_load_date.sql', 'specificColumnTypes': [{'name': 'Border', 'type': 'VARBINARY(MAX)', 'typeCast': 'CAST(? AS VARBINARY(MAX))'}], 'testLoadTable': 'scripts/load_wwi_mssql/tests/load_application_countries.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}}, {'name': 'ApplicationCountriesArchive', 'source': {'schema': 'Application', 'table': 'Countries_Archive', 'loadTable': 'scripts/load_wwi_mssql/load_application_countries.sql', 'fetchNumRecords': 'scripts/load_wwi_mssql/fetch_num_records.sql', 'testCountTable': 'scripts/load_wwi_mssql/tests/validrange_record_count.sql'}, 'destination': {'schema': 'dbo', 'table': 'Application_Countries_Archive', 'stagingTable': 'Application_Countries_Archive_Staging', 'createTable': 'scripts/load_wwi_mssql/create_application_countries.sql', 'modifyTable': [], 'insertTable': 'scripts/load_wwi_mssql/insert_record.sql', 'dropTable': 'scripts/load_wwi_mssql/drop_table.sql', 'dropColumn': 'scripts/load_wwi_mssql/drop_column.sql', 'deleteByLastLoadDateTable': 'scripts/load_wwi_mssql/delete_record_by_la ...
# source_db: {'databaseType': 'mssql', 'database': 'WideWorldImporters', 'conn_spark': 'jdbc:sqlserver://localhost;database=WideWorldImporters;user=sa;password=PP@$$w0rd;encrypt=false', 'conn': 'DRIVER={ODBC Driver 18 for SQL Server};SERVER=localhost,1433;DATABASE=WideWorldImporters;UID=sa;PWD=PP@$$w0rd;TrustServerCertificate=yes'}
# destination_db: {'databaseType': 'mssql', 'database': 'WideWorldImportersDW', 'conn_spark': 'jdbc:sqlserver://localhost;database=WideWorldImportersDW;user=sa;password=PP@$$w0rd;encrypt=false', 'conn': 'DRIVER={ODBC Driver 18 for SQL Server};SERVER=localhost,1433;DATABASE=WideWorldImportersDW;UID=sa;PWD=PP@$$w0rd;TrustServerCertificate=yes'}
# initialCutoffDate: 2012-12-31 00:00:00
# spark_master: local[*]
# spark_jars: ../../resources/jars/mssql-jdbc-13.2.0.jre11.jar
# spark_executor_memory: 3g
# spark_driver_memory: 3g
# spark_executor_cores: 2
# spark_cores_max: 2
# spark_network_timeout: 600s
# spark_executor_heartbeat_interval: 599s
# newCutoffDate: 2013-01-01 00:00:00
# runner_options: ['--runner=DirectRunner']
# gcp_credential: ../resources/credentials/bigquery_token.json
# is_rollback: False
# release_github_repo:
# release_github_branch:

# %%
if source_db["databaseType"].startswith("spark-") and destination_db["databaseType"].startswith("spark-"):
    sql_utils.initialize_spark_session(
        master=spark_master,
        jdbc_url=source_db["conn"], 
        jars=spark_jars, 
        executor_memory=spark_executor_memory, 
        driver_memory=spark_driver_memory, 
        executor_cores=spark_executor_cores, 
        cores_max=spark_cores_max, 
        network_timeout=spark_network_timeout, 
        executor_heartbeat_interval=spark_executor_heartbeat_interval
    )

# %%
def get_last_cutoff_date(table, schema, last_cutoff_dates):
    last_cutoff_date = next((item for item in last_cutoff_dates if item.get("TableName") == table and item.get("SchemaName") == schema), None)

    if last_cutoff_date is None:
        return initialCutoffDate
    else:
        return last_cutoff_date["LastCutoffDate"].strftime("%Y-%m-%d %H:%M:%S")

# %%
class LoadData(beam.DoFn):
    def __init__(self, database_type, conn_str, load_path, values_to_replace, tables_to_replace, show_sql = False, result_type = "tuple", set_timestamp_tostring = False, spark_load_sql = False, database = ""):
        self.database_type = database_type
        self.conn_str = conn_str
        self.load_path = load_path
        self.values_to_replace = values_to_replace
        self.tables_to_replace = tables_to_replace
        self.show_sql = show_sql
        self.result_type = result_type
        self.set_timestamp_tostring = set_timestamp_tostring
        self.spark_load_sql = spark_load_sql
        self.database = database

    def process(self, element):
        sql = sql_utils.get_sql_from_script(
            path=self.load_path, 
            values=self.values_to_replace, 
            tables=self.tables_to_replace,
            directory=script_directory
        )

        if self.show_sql == True:
            print(f"LoadData sql: {sql}")
        
        return sql_utils.select_sql(
            self.conn_str, 
            sql, 
            self.database_type, 
            self.result_type, 
            self.database, 
            spark_jars, 
            spark_master, 
            self.set_timestamp_tostring, 
            False, 
            self.spark_load_sql
        )

# %%
def upsert_data_base(conn, database_type, database, upsert_path, values_to_replace, tables_to_replace, show_sql = False, spark_insert_sql = False):
    sql = sql_utils.get_sql_from_script(
        path=upsert_path, 
        values=values_to_replace, 
        tables=tables_to_replace,
        directory=script_directory
    )
        
    if show_sql == True:
        print(f"""Upsert Data sql:
                {sql} 
                """)
    
    if database_type.startswith("spark-") == False:
        spark_insert_sql = False

    sql_utils.exec_sql(conn, sql, None, database_type, database, spark_master, spark_jars, spark_insert_sql)

# %%
class UpsertData(beam.DoFn):
    def __init__(self, database_type, conn_str, upsert_path, values_to_replace, tables_to_replace, yield_record = None, show_sql = False, yield_element = False, database = "", register_spark_table = None, spark_insert_sql = False):
        self.database_type = database_type
        self.conn_str = conn_str
        self.upsert_path = upsert_path
        self.values_to_replace = values_to_replace
        self.tables_to_replace = tables_to_replace
        self.yield_record = yield_record
        self.show_sql = show_sql
        self.yield_element = yield_element
        self.database = database
        self.register_spark_table = register_spark_table
        self.spark_insert_sql = spark_insert_sql

    def process(self, element):
        upsert_data_base(self.conn_str, self.database_type, self.database, self.upsert_path, self.values_to_replace, self.tables_to_replace, self.show_sql, self.spark_insert_sql)

        if self.register_spark_table is not None and self.database_type.startswith("spark-") == True:
            sql_utils.register_spark_table( 
                spark_master, 
                spark_jars, 
                self.register_spark_table["table_id"], 
                self.register_spark_table["view_name"],
                self.database_type,
                self.conn_str
            )

        if self.yield_record is not None:
            yield self.yield_record
        else:
            if self.yield_element == True:
                yield element

# %%
class CreateTables(beam.DoFn):
    def __init__(self, database_type, conn_str, sql, database, yield_record = None, show_sql = False):
        self.database_type = database_type
        self.conn_str = conn_str
        self.sql = sql
        self.database = database
        self.yield_record = yield_record
        self.show_sql = show_sql

    def process(self, element):
        if len(self.sql) > 0:
            if self.show_sql == True:
                print(f"""Upsert Data sql:
                    {self.sql} 
                    """)
                
                print(f"element: {element}")
                print(f"len element: {len(element)}")

            sql_utils.exec_sql(self.conn_str, self.sql, None, self.database_type, self.database, spark_master, spark_jars)

        if self.yield_record is not None:
            yield self.yield_record

# %%
tc = unittest.TestCase()

class LoadAndWriteData(beam.DoFn):
    def __init__(self, load_config, write_config, assert_config, history_config, modify_config = None, create_staging_config = None, modify_update_config = None, drop_staging_config = None, yield_record = None):
        self.load_config = load_config
        self.write_config = write_config
        self.assert_config = assert_config
        self.history_config = history_config
        self.modify_config = modify_config
        self.create_staging_config = create_staging_config
        self.modify_update_config = modify_update_config
        self.drop_staging_config = drop_staging_config
        self.yield_record = yield_record

    def start_bundle(self):
        self.batch = []
        self.columns = []

    def load_data(self):
        load_sql = sql_utils.get_sql_from_script(
            path=self.load_config["path"], 
            values=self.load_config["values_to_replace"], 
            tables=self.load_config["tables_to_replace"],
            directory=script_directory
        )

        if self.load_config["show_sql"] == True:
            print(f"LoadAndWriteData load data sql: {load_sql}")

        result_type = "tuple"
        if self.load_config["database_type"].startswith("spark-"):
            result_type = "spark-dataframe"

        return sql_utils.select_sql(
            self.load_config["conn"], 
            load_sql, 
            self.load_config["database_type"], 
            result_type, 
            "", 
            spark_jars, 
            spark_master, 
            self.load_config["set_timestamp_tostring"], 
            True
        )
    
    def write_data(self, data):
        sql = self.get_sql(data)

        if self.write_config["show_sql"] == True:
            print(f"write_data sql: {sql}")

        if self.write_config["database_type"].startswith("spark-"):
            sql_utils.exec_sql_batch(
                self.write_config["conn"], 
                sql, 
                data, 
                self.write_config["database_type"],
                self.write_config["database"],
                self.write_config["table_id"])
        else:
            sql_utils.exec_sql_batch(
                self.write_config["conn"], 
                sql, 
                data[1:], 
                self.write_config["database_type"], 
                self.write_config["database"], 
                self.write_config["table_id"])
            
    def get_sql(self, data):
        sql = ""

        if self.write_config["database_type"] == "mssql":
            if len(data) > 0:
                columns = []
                
                for index, col_name in enumerate(data[0]):
                    columns.append(col_name)

                for excluded_column in self.write_config["excluded_columns"]:
                    columns.remove(excluded_column)

                values = []

                for column in columns:
                    excluded_column = next((item for item in self.write_config["specific_column_types"] if item['name'] == column), None)           

                    if excluded_column is None:
                        values.append("?")
                    else:
                        values.append(excluded_column["typeCast"])

                sql = sql_utils.get_sql_from_script(
                    path=self.write_config["path"], 
                    values=self.write_config["values_to_replace"], 
                    tables=[],
                    directory=script_directory
                )

                sql = sql_utils.replace_sql_values(
                    sql, 
                    [
                        { 
                            "name": "Columns",
                            "value": ",".join(columns)
                        },
                        {
                            "name": "ColumnValues",
                            "value": ",".join(values)
                        }
                    ]
                )

        return sql

    def assert_data(self, loaded_data):
        if config["test"] == True:
            if self.assert_config["count_path"] != "" and self.assert_config["load_path"] !=  "":
                testCount = config["testRecordCount"]
                count = 0
                data = []

                if self.assert_config["database_type"].startswith("spark-"):
                    count = loaded_data.count()
                    loaded_data = loaded_data.limit(testCount)
                    
                    if self.assert_config["set_timestamp_tostring"] == True:
                        timestamp_fields = [f.name for f in loaded_data.schema.fields if isinstance(f.dataType, TimestampType)]

                        for col_name in timestamp_fields:
                            # if col_name in loaded_data.columns:
                            loaded_data = loaded_data.withColumn(
                                col_name,
                                date_format(col(col_name), "yyyy-MM-dd HH:mm:ss.SSSSSS")
                            )

                    loaded_data = loaded_data.toPandas()
                    data = loaded_data.replace({np.nan: None}).to_dict(orient="records")
                else:
                    count = len(loaded_data) - 1 
                    loaded_data = loaded_data[:testCount + 1]
                    cols = []
                    
                    for index, col_name in enumerate(loaded_data[0]):
                        cols.append({"index": index, "col_name": col_name})

                    loaded_data.pop(0)

                    data = []
                    for item in loaded_data:
                        row = {}

                        for column in cols:
                            row[column["col_name"]] = item[column["index"]]
                        data.append(row)

                count_sql = sql_utils.get_sql_from_script(
                    path=self.assert_config["count_path"],
                    values=self.assert_config["values_to_replace"], 
                    tables=self.assert_config["tables_to_replace"],
                    directory=script_directory
                )

                expected_data_sql = sql_utils.get_sql_from_script(
                    path=self.assert_config["load_path"], 
                    values=self.assert_config["values_to_replace"], 
                    tables=self.assert_config["tables_to_replace"],
                    directory=script_directory
                )

                if self.assert_config["show_sql"] == True:
                    print(f"count_sql: {count_sql}")
                    print(f"expected_data_sql: {expected_data_sql}")

                expected_data_count = sql_utils.exec_sql_scalar(
                    self.assert_config["conn"], 
                    count_sql, 
                    self.assert_config["database_type"], 
                    self.assert_config["database"], 
                    spark_master, 
                    spark_jars
                )
                expected_data_sample = list(
                    sql_utils.select_sql(
                        self.assert_config["conn"], 
                        expected_data_sql, 
                        self.assert_config["database_type"], 
                        "dictionary", 
                        self.assert_config["database"], 
                        spark_jars, 
                        spark_master, 
                        self.assert_config["set_timestamp_tostring"]
                    )
                )
                
                tc.assertEqual(count, expected_data_count)
                tc.assertListEqual(data, expected_data_sample)

            if len(self.assert_config["assert_tests"]) > 0:
                for assert_test in self.assert_config["assert_tests"]:
                    assert_sql = sql_utils.get_sql_from_script(
                        path=assert_test,
                        values=self.assert_config["values_to_replace"], 
                        tables=self.assert_config["tables_to_replace"],
                        directory=script_directory
                    )
                    
                    assert_result = sql_utils.exec_sql_scalar(
                        self.assert_config["conn"], 
                        assert_sql, 
                        self.assert_config["database_type"], 
                        self.assert_config["database"], 
                        spark_master, 
                        spark_jars
                    )

                    tc.assertEqual(True, assert_result)
                
    
    def insert_load_history(self):
        upsert_data_base(
            self.history_config["conn"],
            self.history_config["database_type"],
            self.history_config["database"],
            self.history_config["upsert_path"],
            self.history_config["values_to_replace"],
            self.history_config["tables_to_replace"],
            self.history_config["show_sql"],
            self.history_config["spark_insert_sql"]
        )

    def modify_table(self):
        upsert_data_base(
            self.modify_config["conn"],
            self.modify_config["database_type"],
            self.modify_config["database"],
            self.modify_config["upsert_path"],
            self.modify_config["values_to_replace"],
            self.modify_config["tables_to_replace"],
            self.modify_config["show_sql"],
            self.modify_config["spark_insert_sql"]
        )

    def create_staging_table(self):
        upsert_data_base(
            self.create_staging_config["conn"],
            self.create_staging_config["database_type"],
            self.create_staging_config["database"],
            self.create_staging_config["upsert_path"],
            self.create_staging_config["values_to_replace"],
            self.create_staging_config["tables_to_replace"],
            self.create_staging_config["show_sql"],
            self.create_staging_config["spark_insert_sql"]
        )

    def modify_update_table(self):
        print(f"modify_update_table show sql: {self.modify_update_config["show_sql"]}")
        upsert_data_base(
            self.modify_update_config["conn"],
            self.modify_update_config["database_type"],
            self.modify_update_config["database"],
            self.modify_update_config["upsert_path"],
            self.modify_update_config["values_to_replace"],
            self.modify_update_config["tables_to_replace"],
            self.modify_update_config["show_sql"],
            self.modify_update_config["spark_insert_sql"]
        )

    def drop_staging_table(self):
        upsert_data_base(
            self.drop_staging_config["conn"],
            self.drop_staging_config["database_type"],
            self.drop_staging_config["database"],
            self.drop_staging_config["upsert_path"],
            self.drop_staging_config["values_to_replace"],
            self.drop_staging_config["tables_to_replace"],
            self.drop_staging_config["show_sql"],
            self.drop_staging_config["spark_insert_sql"]
        )

    def process(self, element):
        # Modify Table
        if self.modify_config is not None:
            self.modify_table()

        # Create Staging
        if self.create_staging_config is not None:
            self.create_staging_table() 

        # Load Data
        loaded_data = None
        if self.load_config is not None:
            loaded_data = self.load_data()

        # Write Data
        if self.write_config is not None:
            self.write_data(loaded_data)

        if self.modify_update_config is not None:
            self.modify_update_table()
        
        # Assert Data
        if self.assert_config is not None:
            self.assert_data(loaded_data)

        # Insert Load History
        self.insert_load_history()

        # Drop Staging
        if self.drop_staging_config is not None:
            self.drop_staging_table()             

        if self.yield_record is not None:
            yield self.yield_record

# %%
def get_last_cutoff_dates():
    sql = sql_utils.get_sql_from_script(
        path=config["loadHistory"]["loadLastCutoffDatesTable"], 
        values=[
            { "name": "Schema", "value": config["loadHistory"]["schema"] },
            { "name": "Table", "value": config["loadHistory"]["table"] },
            { "name": "Database", "value": destination_db["database"] }
        ], 
        tables=[],
        directory=script_directory
    )

    return sql_utils.select_sql(destination_db["conn"], sql, destination_db["databaseType"], "dictionary", destination_db["database"], spark_jars, spark_master, False, False, True)

# %%
def get_create_tables_sql(tables, last_cutoff_dates, new_cutoff_date):
    create_table_sqls = []

    for table in tables:
        tableName = table["destination"]["table"]
        last_cutoff_date = get_last_cutoff_date(tableName, table["destination"]["schema"], last_cutoff_dates)
        lastCutoffDateVal = datetime.strptime(last_cutoff_date, "%Y-%m-%d %H:%M:%S")
        newCutoffDateVal = datetime.strptime(new_cutoff_date, "%Y-%m-%d %H:%M:%S")

        if lastCutoffDateVal < newCutoffDateVal:
            # Create Table
            create_table_sqls.append(
                sql_utils.get_sql_from_script(
                    path=table["destination"]["createTable"], 
                    values=[
                        { "name": "Database", "value": config["destination"]["database"] },
                        { "name": "Schema", "value": table["destination"]["schema"] },
                        { "name": "Table", "value": table["destination"]["table"] },
                        { "name": "NewCutoffDate", "value": new_cutoff_date },
                        { "name": "LastCutoffDate", "value": last_cutoff_date },
                        { "name": "LHSchema", "value": config["loadHistory"]["schema"] },
                        { "name": "LHTable", "value": config["loadHistory"]["table"] },
                        { "name": "TableName", "value": table["destination"]["table"] },
                        { "name": "SchemaName", "value": table["destination"]["schema"] }
                    ], 
                    tables=[],
                    directory=script_directory
                )
            )

            # Delete Records by Last Load Date
            create_table_sqls.append(
                sql_utils.get_sql_from_script(
                    path=table["destination"]["deleteByLastLoadDateTable"], 
                    values=[
                        { "name": "Database", "value": config["destination"]["database"] },
                        { "name": "Schema", "value": table["destination"]["schema"] },
                        { "name": "Table", "value": table["destination"]["table"] },
                        { "name": "NewCutoffDate", "value": new_cutoff_date },
                        { "name": "LastCutoffDate", "value": last_cutoff_date },
                        { "name": "LHSchema", "value": config["loadHistory"]["schema"] },
                        { "name": "LHTable", "value": config["loadHistory"]["table"] },
                        { "name": "TableName", "value": table["destination"]["table"] },
                        { "name": "SchemaName", "value": table["destination"]["schema"] }
                    ], 
                    tables=[],
                    directory=script_directory
                )
            )

    # print(" ".join(create_table_sqls))
    if len(create_table_sqls) > 0:
        return " ".join(create_table_sqls)

    return ""

# %%
def get_process_table(table_name, table, process_table, last_cutoff_date, new_cutoff_date, create_tables_process = None, history_config = None):
    if history_config is None:
        history_config = {
            "conn": destination_db["conn"],
            "database_type": destination_db["databaseType"],
            "database": destination_db["database"],
            "upsert_path": config["loadHistory"]["insertLoadHistoryTable"],
            "values_to_replace": [
                { "name": "TableName", "value": table["destination"]["table"] },
                { "name": "SchemaName", "value": table["destination"]["schema"] },
                { "name": "LoadDate", "value": new_cutoff_date },
                { "name": "LastCutoffDate", "value": last_cutoff_date },
                { "name": "Status", "value": "Successful" },
                { "name": "Details", "value": "" },
                { "name": "Database", "value": destination_db["database"] },
                { "name": "Schema", "value": config["loadHistory"]["schema"] },
                { "name": "Table", "value": config["loadHistory"]["table"] }
            ],
            "tables_to_replace": [],
            "spark_insert_sql": False,
            "show_sql": False
        }
    
    process_table = (
        process_table
        | f"Load and Write Data for Table {table_name}" >> 
            beam.ParDo(
                LoadAndWriteData(
                    load_config={
                        "conn": source_db["conn"],
                        "database_type": source_db["databaseType"],
                        "path": table["source"]["loadTable"],
                        "values_to_replace": [
                            { "name": "Schema", "value": table["source"]["schema"] },
                            { "name": "Table", "value": table["source"]["table"] },
                            { "name": "NewCutoffDate", "value": new_cutoff_date },
                            { "name": "LastCutoffDate", "value": last_cutoff_date },
                        ],
                        "tables_to_replace": [],
                        "set_timestamp_tostring": True,
                        "show_sql": False
                    },
                    write_config={
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "path": table["destination"]["insertTable"],
                        "table_id": f"{destination_db["database"]}.{table["destination"]["schema"]}.{table["destination"]["table"]}",
                        "values_to_replace": [
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["table"] },
                            { "name": "NewCutoffDate", "value": new_cutoff_date },
                            { "name": "LastCutoffDate", "value": last_cutoff_date }
                        ],
                        "tables_to_replace": [],
                        "excluded_columns": [],
                        "specific_column_types": table["destination"]["specificColumnTypes"],
                        "show_sql": False 
                    },
                    assert_config={
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "count_path": table["destination"]["testCountTable"],
                        "load_path": table["destination"]["testLoadTable"],
                        "assert_tests": [],
                        "values_to_replace": [
                            { "name": "Database", "value": destination_db["database"] },
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["table"] },
                            { "name": "NewCutoffDate", "value": new_cutoff_date },
                            { "name": "LastCutoffDate", "value": last_cutoff_date },
                            { "name": "NumberOfRows", "value": str(config["testRecordCount"]) }
                        ],
                        "tables_to_replace": [],
                        "set_timestamp_tostring": True,
                        "show_sql": False
                    },
                    history_config=history_config,
                    yield_record=f"Successfully processed table {table_name} for {new_cutoff_date}"
                )
            )
    )

    if create_tables_process is not None:
        return (
            process_table
            | f"WaitOn Table {table_name}" >> WaitOn(create_tables_process)
            | f"Result Table {table_name}" >> beam.Map(print)
        )
    else:
        return (
            process_table
            | f"Result Table {table_name}" >> beam.Map(print)
        )
        

if is_rollback == False:
    last_cutoff_dates = get_last_cutoff_dates()
    print(f"last_cutoff_dates: {last_cutoff_dates}")
    options = PipelineOptions(runner_options)

    with beam.Pipeline(options=options) as p:
        def modify_table(table, process_table, last_cutoff_dates, waiton_create_tables):
            tableName = table["destination"]["table"]
            last_cutoff_date = get_last_cutoff_date(tableName, table["destination"]["schema"], last_cutoff_dates)
            
            modifyTableScripts = []
                        
            for modifyTableScript in table["destination"]["modifyTable"]:
                modifyTableScripts.append(
                    sql_utils.get_sql_from_script(
                        path=config["modifyLoadHistory"]["loadUnprocessedModifyLoadHistoryScriptTable"],
                        values=[
                            { "name": "ScriptName", "value": modifyTableScript["tableUpdate"] },
                            { "name": "LoadScriptName", "value": modifyTableScript["tableDataLoad"] },
                            { "name": "UpdateScriptName", "value": modifyTableScript["tableDataUpdate"] },
                            { "name": "TestScriptName", "value": modifyTableScript["tableDataTest"] },
                            { "name": "TestCountScriptName", "value": modifyTableScript["tableCountDataTest"] },
                            { "name": "CreateStagingScriptName", "value": modifyTableScript["tableCreateStaging"] },
                            { "name": "AssertTests", "value": ",".join(modifyTableScript["tableAssertTests"]) },
                            { "name": "Name", "value": modifyTableScript["name"] }
                        ],
                        directory=script_directory
                    )
                )
            
            unprocessedScripts = sql_utils.select_spark_sql(
                destination_db["conn"],
                sql_utils.get_sql_from_script(
                    path=config["modifyLoadHistory"]["loadUnprocessedModifyLoadHistoryTable"],
                    values=[
                        { "name": "Database", "value": destination_db["database"] },
                        { "name": "Schema", "value": config["modifyLoadHistory"]["schema"] },
                        { "name": "Table", "value": config["modifyLoadHistory"]["table"] },
                        { "name": "TableName", "value": tableName },
                        { "name": "SchemaName", "value": table["destination"]["schema"] },
                        { "name": "LoadDate", "value": last_cutoff_date },
                        { "name": "LHSchema", "value": config["loadHistory"]["schema"] },
                        { "name": "LHTable", "value": config["loadHistory"]["table"] },
                        { "name": "ModifyTableScripts", "value": " UNION ".join(modifyTableScripts) }
                    ],
                    directory=script_directory
                ),
                destination_db["databaseType"],
                destination_db["database"],
                spark_master,
                spark_jars
            )
            
            for script in unprocessedScripts:
                print(f"Processing '{script["Name"]}' for table {tableName} for cutoff {newCutoffDate}.")

                create_staging_config = None
                if script["CreateStagingScriptName"] != "":
                    create_staging_config = {
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "upsert_path": script["CreateStagingScriptName"],
                        "values_to_replace": [
                            { "name": "Database", "value": destination_db["database"] },
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["stagingTable"] },
                        ],
                        "tables_to_replace": [],
                        "spark_insert_sql": False,
                        "show_sql": False
                    }
                
                load_config = None
                if script["LoadScriptName"] != "":
                    load_config = {
                        "conn": source_db["conn"],
                        "database_type": source_db["databaseType"],
                        "path": script["LoadScriptName"],
                        "values_to_replace": [
                            { "name": "Schema", "value": table["source"]["schema"] },
                            { "name": "Table", "value": table["source"]["table"] },
                            { "name": "LastCutoffDate", "value": last_cutoff_date }
                        ],
                        "tables_to_replace": [],
                        "set_timestamp_tostring": True,
                        "show_sql": False
                    }

                write_config = None
                if script["LoadScriptName"] != "":
                    write_config = {
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "path": table["destination"]["insertTable"],
                        "table_id": f"{destination_db["database"]}.{table["destination"]["schema"]}.{table["destination"]["stagingTable"]}",
                        "values_to_replace": [
                            { "name": "Database", "value": destination_db["database"] },
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["stagingTable"] }
                        ],
                        "tables_to_replace": [],
                        "excluded_columns": [],
                        "specific_column_types": table["destination"]["specificColumnTypes"],
                        "show_sql": False 
                    }

                modify_update_config = None
                if script["UpdateScriptName"] != "":
                    modify_update_config = {
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "upsert_path": script["UpdateScriptName"],
                        "values_to_replace": [
                            { "name": "Database", "value": destination_db["database"] },
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["table"] },
                            { "name": "StagingTable", "value": table["destination"]["stagingTable"] },
                            { "name": "LastCutoffDate", "value": last_cutoff_date }
                        ],
                        "tables_to_replace": [],
                        "spark_insert_sql": False,
                        "show_sql": False
                    }

                drop_staging_config = None
                if script["CreateStagingScriptName"] != "":
                    drop_staging_config = {
                        "conn": destination_db["conn"],
                        "database_type": destination_db["databaseType"],
                        "database": destination_db["database"],
                        "upsert_path": table["destination"]["dropTable"],
                        "values_to_replace": [
                            { "name": "Database", "value": destination_db["database"] },
                            { "name": "Schema", "value": table["destination"]["schema"] },
                            { "name": "Table", "value": table["destination"]["stagingTable"] },
                        ],
                        "tables_to_replace": [],
                        "spark_insert_sql": False,
                        "show_sql": False
                    }

                assert_tests = []
                if len(script["AssertTests"]) > 0:
                    assert_tests = script["AssertTests"].split(",")

                process_table = (
                    process_table
                    | f"Modify Table {tableName} Load and Write Data" >>
                        beam.ParDo(
                            LoadAndWriteData(
                                modify_config={
                                    "conn": destination_db["conn"],
                                    "database_type": destination_db["databaseType"],
                                    "database": destination_db["database"],
                                    "upsert_path": script["ScriptName"],
                                    "values_to_replace": [
                                        { "name": "Database", "value": destination_db["database"] },
                                        { "name": "Schema", "value": table["destination"]["schema"] },
                                        { "name": "Table", "value": table["destination"]["table"] },
                                    ],
                                    "tables_to_replace": [],
                                    "spark_insert_sql": False,
                                    "show_sql": False
                                },
                                create_staging_config=create_staging_config,
                                load_config=load_config,
                                write_config=write_config,
                                modify_update_config=modify_update_config,
                                assert_config={
                                    "conn": destination_db["conn"],
                                    "database_type": destination_db["databaseType"],
                                    "database": destination_db["database"],
                                    "count_path": script["TestCountScriptName"],
                                    "load_path": script["TestScriptName"],
                                    "assert_tests": assert_tests,
                                    "values_to_replace": [
                                        { "name": "Database", "value": destination_db["database"] },
                                        { "name": "Schema", "value": table["destination"]["schema"] },
                                        { "name": "Table", "value": table["destination"]["table"] },
                                        { "name": "LastCutoffDate", "value": last_cutoff_date },
                                        { "name": "NewCutoffDate", "value": newCutoffDate },
                                        { "name": "NumberOfRows", "value": str(config["testRecordCount"]) }
                                    ],
                                    "tables_to_replace": [],
                                    "set_timestamp_tostring": True,
                                    "show_sql": False
                                },
                                history_config={
                                    "conn": destination_db["conn"],
                                    "database_type": destination_db["databaseType"],
                                    "database": destination_db["database"],
                                    "upsert_path": config["modifyLoadHistory"]["insertModifyLoadHistoryTable"],
                                    "values_to_replace": [
                                        { "name": "Database", "value": destination_db["database"] },
                                        { "name": "Schema", "value": config["modifyLoadHistory"]["schema"] },
                                        { "name": "Table", "value": config["modifyLoadHistory"]["table"] },
                                        { "name": "TableName", "value": tableName },
                                        { "name": "SchemaName", "value": table["destination"]["schema"] },
                                        { "name": "LoadDate", "value": last_cutoff_date },
                                        { "name": "LastCutoffDate", "value": last_cutoff_date },
                                        { "name": "Status", "value": "Successful" },
                                        { "name": "Details", "value": "" },
                                        { "name": "ScriptName", "value": script["Name"] }
                                    ],
                                    "tables_to_replace": [],
                                    "spark_insert_sql": False,
                                    "show_sql": False
                                },
                                drop_staging_config=drop_staging_config,
                                yield_record={f"Successfully modified table {tableName} for {newCutoffDate}"}
                            )
                        )
                    | f"Modify Table {tableName} WaitOn 1" >> WaitOn(waiton_create_tables)
                )

            return process_table
        
        # create Load History Date table
        create_load_history_date = (
            p 
            | "Input Create Load History Date Table" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
            | "Create Load History Date Table" >>
                beam.ParDo(
                    UpsertData(
                        destination_db["databaseType"],
                        destination_db["conn"],
                        config["loadHistoryDate"]["createLoadHistoryDateTable"],
                        [
                            { "name": "Database", "value": config["destination"]["database"] },
                            { "name": "Schema", "value": config["loadHistoryDate"]["schema"] },
                            { "name": "Table", "value": config["loadHistoryDate"]["table"] }
                        ],
                        [],
                        { "Successfully created Load History table" },
                        False,
                        False,
                        destination_db["database"] 
                    )
                )
            | "Print Load History Date Table" >> beam.Map(print)
        )

        # create Load History table
        create_load_history = (
            p 
            | "Input Create Load History Table" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
            | "Create Load History Table" >> 
                beam.ParDo(
                    UpsertData(
                        destination_db["databaseType"],
                        destination_db["conn"],
                        config["loadHistory"]["createLoadHistoryTable"],
                        [
                            { "name": "Database", "value": config["destination"]["database"] },
                            { "name": "Schema", "value": config["loadHistory"]["schema"] },
                            { "name": "Table", "value": config["loadHistory"]["table"] }
                        ],
                        [],
                        { "Successfully created Load History table" },
                        False,
                        False,
                        destination_db["database"] 
                    )
                )
            | "Print Load History Table" >> beam.Map(print) 
        )

        # create Modify Load History table
        create_modify_load_history = (
            p 
            | "Input Create Modify Load History Table" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
            | "Create Modify Load History Table" >> 
                beam.ParDo(
                    UpsertData(
                        destination_db["databaseType"],
                        destination_db["conn"],
                        config["modifyLoadHistory"]["createModifyLoadHistoryTable"],
                        [
                            { "name": "Database", "value": config["destination"]["database"] },
                            { "name": "Schema", "value": config["modifyLoadHistory"]["schema"] },
                            { "name": "Table", "value": config["modifyLoadHistory"]["table"] }
                        ],
                        [],
                        { "Successfully created Modify Load History table" },
                        False,
                        False,
                        destination_db["database"]
                    )
                )
            | "Print Modify Load History Table" >> beam.Map(print)
        )

        create_tables_sql = get_create_tables_sql(tables, last_cutoff_dates, newCutoffDate)
        create_tables = (
            p
            | "Input Create Tables" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
            | "Create Tables" >> beam.ParDo(
                CreateTables(
                    destination_db["databaseType"],
                    destination_db["conn"],
                    create_tables_sql,
                    destination_db["database"],
                    { f"Successfully created tables." },
                    False
                )
            )
            | "Wait On History Tables" >> WaitOn(
                create_load_history, 
                create_modify_load_history, 
                create_load_history_date
            )
            | "Print Create Tables" >> beam.Map(print)
        )

        process_table_processes = []
        
        for table in tables:
            tableName = table["destination"]["table"]
            
            print(f"Processing table '{tableName}' for '{newCutoffDate}'.")

            last_cutoff_date = get_last_cutoff_date(tableName, table["destination"]["schema"], last_cutoff_dates)
            lastCutoffDateVal = datetime.strptime(last_cutoff_date, "%Y-%m-%d %H:%M:%S")
            newCutoffDateVal = datetime.strptime(newCutoffDate, "%Y-%m-%d %H:%M:%S")
            
            if lastCutoffDateVal >= newCutoffDateVal:
                print(f"Table '{tableName}' has already been loaded for '{newCutoffDate}'.")
            else:

                process_table = p | f"Input Create Table for {tableName}" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])

                if len(table["destination"]["modifyTable"]) > 0:
                    process_table = modify_table(table, process_table, last_cutoff_dates, create_tables)

                process_table = get_process_table(tableName, table, process_table, last_cutoff_date, newCutoffDate, create_tables)
                process_table_processes.append(process_table)
        
        # Create load history date
        # if len(process_table_processes) > 0:
        (
            p 
            | "Input Insert Load History Date Table" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
            | "Insert Load History Date Table" >> 
                beam.ParDo(
                    UpsertData(
                        destination_db["databaseType"],
                        destination_db["conn"],
                        config["loadHistoryDate"]["insertLoadHistoryDateTable"],
                        [
                            { "name": "Database", "value": config["destination"]["database"] },
                            { "name": "Schema", "value": config["loadHistoryDate"]["schema"] },
                            { "name": "Table", "value": config["loadHistoryDate"]["table"] },
                            { "name": "NewCutoffDate", "value": newCutoffDate },
                            { "name": "Status", "value": "Successful" },
                            { "name": "ArchivePath", "value": archivePath },
                            { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                            { "name": "TableLH", "value": config["loadHistory"]["table"] },
                            { "name": "Tables", "value": ",".join(list(table["destination"]["schema"] + "." + table["destination"]["table"] for table in config["tables"])) },
                            { "name": "ReleaseGithubRepo", "value": release_github_repo },
                            { "name": "ReleaseGithubBranch", "value": release_github_branch }
                        ],
                        [],
                        { "Successfully created Load History table" },
                        False,
                        False,
                        destination_db["database"] 
                    )
                )
            | f"WaitOn Insert Load History Date" >> WaitOn(*process_table_processes)
            | "Print Insert History Date Table" >> beam.Map(print) 
        )
# Out:
# last_cutoff_dates: [{'TableName': 'Application_Cities', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_Cities_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_Countries', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_Countries_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_DeliveryMethods', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_DeliveryMethods_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_PaymentMethods', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_PaymentMethods_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_People', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_People_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_StateProvinces', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_StateProvinces_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_TransactionTypes', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Application_TransactionTypes_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_PurchaseOrderLines', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_PurchaseOrders', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_SupplierCategories', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_SupplierCategories_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_Suppliers', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_Suppliers_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Purchasing_SupplierTransactions', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_BuyingGroups', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_BuyingGroups_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_CustomerCategories', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_CustomerCategories_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_Customers', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_Customers_Archive', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_CustomerTransctions', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_InvoiceLines', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_Invoices', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_OrderLines', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Sales_Orders', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Warehouse_Colors', 'SchemaName': 'dbo', 'LastCutoffDate': datetime.datetime(2013, 1, 1, 0, 0)}, {'TableName': 'Warehous ...
# Processing table 'Application_Cities' for '2013-01-01 00:00:00'.
# Table 'Application_Cities' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_Cities_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_Cities_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_Countries' for '2013-01-01 00:00:00'.
# Table 'Application_Countries' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_Countries_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_Countries_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_DeliveryMethods' for '2013-01-01 00:00:00'.
# Table 'Application_DeliveryMethods' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_DeliveryMethods_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_DeliveryMethods_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_PaymentMethods' for '2013-01-01 00:00:00'.
# Table 'Application_PaymentMethods' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_PaymentMethods_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_PaymentMethods_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_People' for '2013-01-01 00:00:00'.
# Table 'Application_People' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_People_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_People_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_StateProvinces' for '2013-01-01 00:00:00'.
# Table 'Application_StateProvinces' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_StateProvinces_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_StateProvinces_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_TransactionTypes' for '2013-01-01 00:00:00'.
# Table 'Application_TransactionTypes' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Application_TransactionTypes_Archive' for '2013-01-01 00:00:00'.
# Table 'Application_TransactionTypes_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_PurchaseOrderLines' for '2013-01-01 00:00:00'.
# Table 'Purchasing_PurchaseOrderLines' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_PurchaseOrders' for '2013-01-01 00:00:00'.
# Table 'Purchasing_PurchaseOrders' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_SupplierCategories' for '2013-01-01 00:00:00'.
# Table 'Purchasing_SupplierCategories' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_SupplierCategories_Archive' for '2013-01-01 00:00:00'.
# Table 'Purchasing_SupplierCategories_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_Suppliers' for '2013-01-01 00:00:00'.
# Table 'Purchasing_Suppliers' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_Suppliers_Archive' for '2013-01-01 00:00:00'.
# Table 'Purchasing_Suppliers_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Purchasing_SupplierTransactions' for '2013-01-01 00:00:00'.
# Table 'Purchasing_SupplierTransactions' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_BuyingGroups' for '2013-01-01 00:00:00'.
# Table 'Sales_BuyingGroups' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_BuyingGroups_Archive' for '2013-01-01 00:00:00'.
# Table 'Sales_BuyingGroups_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_CustomerCategories' for '2013-01-01 00:00:00'.
# Table 'Sales_CustomerCategories' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_CustomerCategories_Archive' for '2013-01-01 00:00:00'.
# Table 'Sales_CustomerCategories_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_Customers' for '2013-01-01 00:00:00'.
# Table 'Sales_Customers' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_Customers_Archive' for '2013-01-01 00:00:00'.
# Table 'Sales_Customers_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_CustomerTransctions' for '2013-01-01 00:00:00'.
# Table 'Sales_CustomerTransctions' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_InvoiceLines' for '2013-01-01 00:00:00'.
# Table 'Sales_InvoiceLines' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_Invoices' for '2013-01-01 00:00:00'.
# Table 'Sales_Invoices' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_OrderLines' for '2013-01-01 00:00:00'.
# Table 'Sales_OrderLines' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Sales_Orders' for '2013-01-01 00:00:00'.
# Table 'Sales_Orders' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_Colors' for '2013-01-01 00:00:00'.
# Table 'Warehouse_Colors' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_Colors_Archive' for '2013-01-01 00:00:00'.
# Table 'Warehouse_Colors_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_PackageTypes' for '2013-01-01 00:00:00'.
# Table 'Warehouse_PackageTypes' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_PackageTypes_Archive' for '2013-01-01 00:00:00'.
# Table 'Warehouse_PackageTypes_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockGroups' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockGroups' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockGroups_Archive' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockGroups_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockItemHoldings' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockItemHoldings' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockItems' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockItems' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockItems_Archive' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockItems_Archive' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockItemStockGroups' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockItemStockGroups' has already been loaded for '2013-01-01 00:00:00'.
# Processing table 'Warehouse_StockItemTransactions' for '2013-01-01 00:00:00'.
# Table 'Warehouse_StockItemTransactions' has already been loaded for '2013-01-01 00:00:00'.
# {'Successfully created Load History table'}
# {'Successfully created Modify Load History table'}
# {'Successfully created Load History table'}
# {'Successfully created Load History table'}
# {'Successfully created tables.'}

# %%
tc = unittest.TestCase()

class RollbackDropRecordsData(beam.DoFn):
    def __init__(self, rollback_config, assert_config, rollback_final_config, yield_record = None):
        self.rollback_config = rollback_config
        self.assert_config = assert_config
        self.rollback_final_config = rollback_final_config
        self.yield_record = yield_record

    def assert_data(self):
        if config["test"] == True:
            source_count_sql = sql_utils.get_sql_from_script(
                path=self.assert_config["source"]["count_path"],
                values=self.assert_config["source"]["values_to_replace"], 
                tables=self.assert_config["source"]["tables_to_replace"],
                directory=script_directory
            )

            source_data_sql = sql_utils.get_sql_from_script(
                path=self.assert_config["source"]["load_path"], 
                values=self.assert_config["source"]["values_to_replace"], 
                tables=self.assert_config["source"]["tables_to_replace"],
                directory=script_directory
            ) + " " + sql_utils.get_sql_from_script(
                path=self.assert_config["source"]["fetch_num_rows_path"], 
                values=self.assert_config["source"]["values_to_replace"], 
                tables=self.assert_config["source"]["tables_to_replace"],
                directory=script_directory
            )

            expected_count_sql = sql_utils.get_sql_from_script(
                path=self.assert_config["destination"]["count_path"],
                values=self.assert_config["destination"]["values_to_replace"], 
                tables=self.assert_config["destination"]["tables_to_replace"],
                directory=script_directory
            )

            expected_data_sql = sql_utils.get_sql_from_script(
                path=self.assert_config["destination"]["load_path"], 
                values=self.assert_config["destination"]["values_to_replace"], 
                tables=self.assert_config["destination"]["tables_to_replace"],
                directory=script_directory
            )

            if self.assert_config["show_sql"] == True:
                print(f"source_count_sql: {source_count_sql}")
                print(f"source_data_sql: {source_data_sql}")
                print(f"expected_count_sql: {expected_count_sql}")
                print(f"expected_data_sql: {expected_data_sql}")

            source_data_count = sql_utils.exec_sql_scalar(
                self.assert_config["source"]["conn"], 
                source_count_sql, 
                self.assert_config["source"]["database_type"], 
                self.assert_config["source"]["database"], 
                spark_master, 
                spark_jars
            )

            source_data_sample = list(
                sql_utils.select_sql(
                    self.assert_config["source"]["conn"], 
                    source_data_sql, 
                    self.assert_config["source"]["database_type"], 
                    "dictionary", 
                    self.assert_config["source"]["database"], 
                    spark_jars, 
                    spark_master, 
                    self.assert_config["source"]["set_timestamp_tostring"]
                )
            )
            
            expected_data_count = sql_utils.exec_sql_scalar(
                self.assert_config["destination"]["conn"], 
                expected_count_sql, 
                self.assert_config["destination"]["database_type"], 
                self.assert_config["destination"]["database"], 
                spark_master, 
                spark_jars
            )

            expected_data_sample = list(
                sql_utils.select_sql(
                    self.assert_config["destination"]["conn"], 
                    expected_data_sql, 
                    self.assert_config["destination"]["database_type"], 
                    "dictionary", 
                    self.assert_config["destination"]["database"], 
                    spark_jars, 
                    spark_master, 
                    self.assert_config["destination"]["set_timestamp_tostring"]
                )
            )
            
            tc.assertEqual(source_data_count, expected_data_count)
            tc.assertListEqual(source_data_sample, expected_data_sample)

    def rollback_data(self):
        added_columns_sql = []

        if len(self.rollback_config["added_columns"]) > 0:
            for column in self.rollback_config["added_columns"].split(","):
                added_columns_sql.append(
                    sql_utils.get_sql_from_script(
                        path=table["destination"]["dropColumn"], 
                        values=self.rollback_config["values_to_replace_drop_columns"] + [
                            { "name": "Column", "value": column }
                        ], 
                        tables=[],
                        directory=script_directory
                    )
                )

        upsert_data_base(
            conn=self.rollback_config["conn"],
            database_type=self.rollback_config["database_type"],
            database=self.rollback_config["database"],
            upsert_path=self.rollback_config["path"],
            values_to_replace=self.rollback_config["values_to_replace"] + [{ "name": "DropColumns", "value": " ".join(added_columns_sql) }],
            tables_to_replace=self.rollback_config["tables_to_replace"],
            show_sql=self.rollback_config["show_sql"]
        )

    def rollback_final_data(self):
        upsert_data_base(
            conn=self.rollback_final_config["conn"],
            database_type=self.rollback_final_config["database_type"],
            database=self.rollback_final_config["database"],
            upsert_path=self.rollback_final_config["path"],
            values_to_replace=self.rollback_final_config["values_to_replace"],
            tables_to_replace=self.rollback_final_config["tables_to_replace"],
            show_sql=self.rollback_final_config["show_sql"]
        )
        
    def process(self, element):
        # rollback data
        self.rollback_data()

        # assert data
        self.assert_data()

        # update/delete load histories
        self.rollback_final_data()

        if self.yield_record is not None:
            yield self.yield_record

# %%
def get_load_history_date_by_load_date(load_date):
    sql = sql_utils.get_sql_from_script(
        path=config["loadHistoryDate"]["loadLoadHistoryDateTable"], 
        values=[
            { "name": "Schema", "value": config["loadHistoryDate"]["schema"] },
            { "name": "Table", "value": config["loadHistoryDate"]["table"] },
            { "name": "Database", "value": destination_db["database"] },
            { "name": "LoadDate", "value": load_date }
        ], 
        tables=[],
        directory=script_directory
    )

    result = sql_utils.select_sql(
        destination_db["conn"], 
        sql, 
        destination_db["databaseType"], 
        "dictionary", 
        destination_db["database"], 
        spark_jars, 
        spark_master, 
        False, 
        False, 
        True
    )

    if len(result) > 0:
        return result[0]
    
    return None

def get_load_histories_for_rollback(load_date):
    sql = sql_utils.get_sql_from_script(
        path=config["loadHistory"]["loadLoadHistoriesForRollback"], 
        values=[
            { "name": "Schema", "value": config["loadHistory"]["schema"] },
            { "name": "Table", "value": config["loadHistory"]["table"] },
            { "name": "Database", "value": destination_db["database"] },
            { "name": "LoadDate", "value": load_date }
        ], 
        tables=[],
        directory=script_directory
    )

    return sql_utils.select_sql(
        destination_db["conn"], 
        sql, 
        destination_db["databaseType"], 
        "dictionary", 
        destination_db["database"], 
        spark_jars, 
        spark_master, 
        False, 
        False, 
        True
    )

# %%
if is_rollback == True:
    load_history_date_data = get_load_history_date_by_load_date(newCutoffDate)
    
    if load_history_date_data is None:
        raise Exception(f"There is no loaded history for the rollback date {newCutoffDate}.")
    
    load_histories_for_rollback = get_load_histories_for_rollback(newCutoffDate)
    print(f"load_histories_for_rollback: {load_histories_for_rollback}")

    options = PipelineOptions(runner_options)
    
    with beam.Pipeline(options=options) as p:
        rollback_table_processes = []

        for tableHistory in load_histories_for_rollback:
            tableName = tableHistory["TableName"]
            rollback_type = tableHistory["Type"]

            if rollback_type == "Load Date Is Latest":
                print(f"Table {tableName} latest load date is already {newCutoffDate}.")
            else:
                table = next(
                    (
                        table 
                        for table in tables 
                        if (
                            table["destination"]["table"] == tableHistory["TableName"] and 
                            table["destination"]["schema"] == tableHistory["SchemaName"]
                        )
                    ), 
                    None
                )
                
                added_columns = tableHistory["AddedColumns"]
                load_last_cutoff_date = tableHistory["LoadLastCutoffDate"].strftime("%Y-%m-%d %H:%M:%S")

                print(f"Processing rollback of table '{tableName}' for '{newCutoffDate}'.")

                if table is not None:
                    if rollback_type == "Drop Records":
                        rollback_table_processes.append(
                            (
                                p 
                                | f"Input Rollback Table {tableName}" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
                                | f"Rollback Table {tableName}" >> beam.ParDo(
                                        RollbackDropRecordsData(
                                            rollback_config={
                                                "conn": destination_db["conn"],
                                                "database_type": destination_db["databaseType"],
                                                "database": destination_db["database"],
                                                "path": config["rollBack"]["rollbackDropRecordsTable"],
                                                "values_to_replace": [
                                                    { "name": "Database", "value": config["destination"]["database"] },
                                                    { "name": "Schema", "value": table["destination"]["schema"] },
                                                    { "name": "Table", "value": table["destination"]["table"] },
                                                    { "name": "LoadDate", "value": newCutoffDate }
                                                ],
                                                "values_to_replace_drop_columns": [
                                                    { "name": "Database", "value": config["destination"]["database"] },
                                                    { "name": "Schema", "value": table["destination"]["schema"] },
                                                    { "name": "Table", "value": table["destination"]["table"] }
                                                ],
                                                "tables_to_replace": [],
                                                "set_timestamp_tostring": False,
                                                "show_sql": False,
                                                "added_columns": added_columns
                                            },
                                            assert_config={
                                                "source": {
                                                    "conn": source_db["conn"],
                                                    "database_type": source_db["databaseType"],
                                                    "database": source_db["database"],
                                                    "count_path": table["source"]["testCountTable"],
                                                    "load_path": table["source"]["loadTable"],
                                                    "fetch_num_rows_path": table["source"]["fetchNumRecords"],
                                                    "values_to_replace": [
                                                        { "name": "Database", "value": source_db["database"] },
                                                        { "name": "Schema", "value": table["source"]["schema"] },
                                                        { "name": "Table", "value": table["source"]["table"] },
                                                        { "name": "NewCutoffDate", "value": newCutoffDate },
                                                        { "name": "LastCutoffDate", "value": load_last_cutoff_date },
                                                        { "name": "NumberOfRows", "value": str(config["testRecordCount"]) }
                                                    ],
                                                    "tables_to_replace": [],
                                                    "set_timestamp_tostring": True
                                                },
                                                "destination": {
                                                    "conn": destination_db["conn"],
                                                    "database_type": destination_db["databaseType"],
                                                    "database": destination_db["database"],
                                                    "count_path": table["destination"]["testCountTable"],
                                                    "load_path": table["destination"]["testLoadTable"],
                                                    "values_to_replace": [
                                                        { "name": "Database", "value": destination_db["database"] },
                                                        { "name": "Schema", "value": table["destination"]["schema"] },
                                                        { "name": "Table", "value": table["destination"]["table"] },
                                                        { "name": "NewCutoffDate", "value": newCutoffDate },
                                                        { "name": "LastCutoffDate", "value": load_last_cutoff_date },
                                                        { "name": "NumberOfRows", "value": str(config["testRecordCount"]) }
                                                    ],
                                                    "tables_to_replace": [],
                                                    "set_timestamp_tostring": True
                                                },
                                                "show_sql": False
                                            },
                                            rollback_final_config={
                                                "conn": destination_db["conn"],
                                                "database_type": destination_db["databaseType"],
                                                "database": destination_db["database"],
                                                "path": config["rollBack"]["rollbackDropRecordsFinalTable"],
                                                "values_to_replace": [
                                                    { "name": "Database", "value": config["destination"]["database"] },
                                                    { "name": "Schema", "value": table["destination"]["schema"] },
                                                    { "name": "Table", "value": table["destination"]["table"] },
                                                    { "name": "LoadDate", "value": newCutoffDate },
                                                    { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                                                    { "name": "TableLH", "value": config["loadHistory"]["table"] },
                                                    { "name": "SchemaMLH", "value": config["modifyLoadHistory"]["schema"] },
                                                    { "name": "TableMLH", "value": config["modifyLoadHistory"]["table"] },
                                                ],
                                                "tables_to_replace": [],
                                                "set_timestamp_tostring": False,
                                                "show_sql": False,
                                                "added_columns": added_columns
                                            },
                                            yield_record={ f"Successfully rolled back table {tableName} to {newCutoffDate}." }
                                        )
                                    )
                                | f"Print Rollback Table {tableName}" >> beam.Map(print)
                            )
                        )
                        
                    elif rollback_type == "Recreate Table":
                        process_table = (
                            p 
                            | f"Input Rollback Table {tableName}" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
                            | f"Rollback Table {tableName}" >>
                                    beam.ParDo(
                                        UpsertData(
                                            destination_db["databaseType"],
                                            destination_db["conn"],
                                            config["rollBack"]["rollbackRecreateTable"],
                                            [
                                                { "name": "Database", "value": destination_db["database"] },
                                                { "name": "Schema", "value": table["destination"]["schema"] },
                                                { "name": "Table", "value": table["destination"]["table"] },
                                                { "name": "LoadDate", "value": newCutoffDate },
                                                { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                                                { "name": "TableLH", "value": config["loadHistory"]["table"] },
                                                { "name": "SchemaMLH", "value": config["modifyLoadHistory"]["schema"] },
                                                { "name": "TableMLH", "value": config["modifyLoadHistory"]["table"] }
                                            ],
                                            [],
                                            { "Successfully removed table" },
                                            False,
                                            False,
                                            destination_db["database"] 
                                        )
                                    )
                            | f"Rollback Create Table {tableName}" >>
                                    beam.ParDo(
                                        UpsertData(
                                            destination_db["databaseType"],
                                            destination_db["conn"],
                                            table["destination"]["createTable"],
                                            [
                                                { "name": "Database", "value": destination_db["database"] },
                                                { "name": "Schema", "value": table["destination"]["schema"] },
                                                { "name": "Table", "value": table["destination"]["table"] },
                                                { "name": "NewCutoffDate", "value": newCutoffDate },
                                                { "name": "LHSchema", "value": config["loadHistory"]["schema"] },
                                                { "name": "LHTable", "value": config["loadHistory"]["table"] },
                                                { "name": "TableName", "value": table["destination"]["table"] }
                                            ],
                                            [],
                                            { "Successfully created table" },
                                            False,
                                            False,
                                            destination_db["database"] 
                                        )
                                    )
                        )

                        process_table = get_process_table(
                            table_name=tableName, 
                            table=table, 
                            process_table=process_table, 
                            last_cutoff_date=initialCutoffDate, 
                            new_cutoff_date=newCutoffDate, 
                            create_tables_process=None,
                            history_config={
                                "conn": destination_db["conn"],
                                "database_type": destination_db["databaseType"],
                                "database": destination_db["database"],
                                "upsert_path": config["loadHistory"]["updateLoadHistoryLastRolledBackProcessedDateTable"],
                                "values_to_replace": [
                                    { "name": "TableName", "value": table["destination"]["table"] },
                                    { "name": "SchemaName", "value": table["destination"]["schema"] },
                                    { "name": "LoadDate", "value": newCutoffDate },
                                    { "name": "Database", "value": destination_db["database"] },
                                    { "name": "Schema", "value": config["loadHistory"]["schema"] },
                                    { "name": "Table", "value": config["loadHistory"]["table"] }
                                ],
                                "tables_to_replace": [],
                                "spark_insert_sql": False,
                                "show_sql": False
                            } 
                        )

                        process_table = (
                            process_table 
                            | f"Rollback Updadate/Delete Histories Table {tableName}" >>
                                    beam.ParDo(
                                        UpsertData(
                                            destination_db["databaseType"],
                                            destination_db["conn"],
                                            config["rollBack"]["rollbackRecreateFinalTable"],
                                            [
                                                { "name": "Database", "value": destination_db["database"] },
                                                { "name": "Schema", "value": table["destination"]["schema"] },
                                                { "name": "Table", "value": table["destination"]["table"] },
                                                { "name": "LoadDate", "value": newCutoffDate },
                                                { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                                                { "name": "TableLH", "value": config["loadHistory"]["table"] },
                                                { "name": "SchemaMLH", "value": config["modifyLoadHistory"]["schema"] },
                                                { "name": "TableMLH", "value": config["modifyLoadHistory"]["table"] }
                                            ],
                                            [],
                                            { "Successfully removed table" },
                                            False,
                                            False,
                                            destination_db["database"] 
                                        )
                                    )
                        )

                        rollback_table_processes.append(process_table)
                else:
                    if rollback_type == "Drop Table":
                        rollback_table_processes.append(
                            (
                                p 
                                | f"Input Rollback Table {tableName}" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
                                | f"Rollback Table {tableName}" >>
                                        beam.ParDo(
                                            UpsertData(
                                                destination_db["databaseType"],
                                                destination_db["conn"],
                                                config["rollBack"]["rollbackDropTable"],
                                                [
                                                    { "name": "Database", "value": destination_db["database"] },
                                                    { "name": "Schema", "value": tableHistory["SchemaName"] },
                                                    { "name": "Table", "value": tableHistory["TableName"] },
                                                    { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                                                    { "name": "TableLH", "value": config["loadHistory"]["table"] },
                                                    { "name": "SchemaMLH", "value": config["modifyLoadHistory"]["schema"] },
                                                    { "name": "TableMLH", "value": config["modifyLoadHistory"]["table"] }
                                                ],
                                                [],
                                                { "Successfully removed table" },
                                                False,
                                                False,
                                                destination_db["database"] 
                                            )
                                        )
                            )
                        )

        if len(rollback_table_processes) > 0:
            (
                p 
                | f"Input Rollback Load History Date Table" >> beam.Create([{ "PlaceHolder": "Temp 1 record" }])
                | f"Rollback Load History Date Table" >>
                        beam.ParDo(
                            UpsertData(
                                destination_db["databaseType"],
                                destination_db["conn"],
                                config["loadHistoryDate"]["deleteLoadHistoryDatesForRollback"],
                                [
                                    { "name": "Database", "value": destination_db["database"] },
                                    { "name": "Schema", "value": config["loadHistoryDate"]["schema"] },
                                    { "name": "Table", "value": config["loadHistoryDate"]["table"] },
                                    { "name": "SchemaLH", "value": config["loadHistory"]["schema"] },
                                    { "name": "TableLH", "value": config["loadHistory"]["table"] },
                                    { "name": "LoadDate", "value": newCutoffDate }
                                ],
                                [],
                                { "Successfully rolled back Load History Date" },
                                False,
                                False,
                                destination_db["database"] 
                            )
                        )
                | f"WaitOn Rollback Load History Date" >> WaitOn(*rollback_table_processes)
                | "Print Rollback Load History Date" >> beam.Map(print)
            )
# Out:
# load_histories_for_rollback: [{'TableName': 'Application_Cities', 'SchemaName': 'WideWorldImporters2', 'Type': 'Drop Records', 'AddedColumns': 'NewColumn', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Application_Cities_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Drop Records', 'AddedColumns': 'NewColumn', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Warehouse_Colors', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Warehouse_Colors_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Sales_Orders', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Application_People', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Application_People_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Application_Countries', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Application_Countries_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Sales_Invoices', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Sales_Customers_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Sales_Customers', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Purchasing_Suppliers_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Purchasing_Suppliers', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Sales_OrderLines', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Warehouse_StockItemHoldings', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Warehouse_StockItems', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Warehouse_StockItems_Archive', 'SchemaName': 'WideWorldImporters2', 'Type': 'Load Date Is Latest', 'AddedColumns': '', 'LoadLastCutoffDate': datetime.datetime(2012, 12, 31, 0, 0, tzinfo=datetime.timezone.utc)}, {'TableName': 'Wareho ...
# Processing rollback of table 'Application_Cities' for '2013-01-01 00:00:00'.
# Processing rollback of table 'Application_Cities_Archive' for '2013-01-01 00:00:00'.
# Table Warehouse_Colors latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_Colors_Archive latest load date is already 2013-01-01 00:00:00.
# Table Sales_Orders latest load date is already 2013-01-01 00:00:00.
# Table Application_People latest load date is already 2013-01-01 00:00:00.
# Table Application_People_Archive latest load date is already 2013-01-01 00:00:00.
# Table Application_Countries latest load date is already 2013-01-01 00:00:00.
# Table Application_Countries_Archive latest load date is already 2013-01-01 00:00:00.
# Table Sales_Invoices latest load date is already 2013-01-01 00:00:00.
# Table Sales_Customers_Archive latest load date is already 2013-01-01 00:00:00.
# Table Sales_Customers latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_Suppliers_Archive latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_Suppliers latest load date is already 2013-01-01 00:00:00.
# Table Sales_OrderLines latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockItemHoldings latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockItems latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockItems_Archive latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockGroups_Archive latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockGroups latest load date is already 2013-01-01 00:00:00.
# Table Sales_BuyingGroups latest load date is already 2013-01-01 00:00:00.
# Table Sales_BuyingGroups_Archive latest load date is already 2013-01-01 00:00:00.
# Table Sales_InvoiceLines latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_PackageTypes latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_PackageTypes_Archive latest load date is already 2013-01-01 00:00:00.
# Table Application_PaymentMethods latest load date is already 2013-01-01 00:00:00.
# Table Application_PaymentMethods_Archive latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_PurchaseOrders latest load date is already 2013-01-01 00:00:00.
# Table Application_StateProvinces latest load date is already 2013-01-01 00:00:00.
# Table Application_StateProvinces_Archive latest load date is already 2013-01-01 00:00:00.
# Table Application_DeliveryMethods latest load date is already 2013-01-01 00:00:00.
# Table Application_DeliveryMethods_Archive latest load date is already 2013-01-01 00:00:00.
# Table Application_TransactionTypes_Archive latest load date is already 2013-01-01 00:00:00.
# Table Application_TransactionTypes latest load date is already 2013-01-01 00:00:00.
# Table Sales_CustomerCategories latest load date is already 2013-01-01 00:00:00.
# Table Sales_CustomerCategories_Archive latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_SupplierCategories latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_SupplierCategories_Archive latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_PurchaseOrderLines latest load date is already 2013-01-01 00:00:00.
# Table Sales_CustomerTransctions latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockItemStockGroups latest load date is already 2013-01-01 00:00:00.
# Table Purchasing_SupplierTransactions latest load date is already 2013-01-01 00:00:00.
# Table Warehouse_StockItemTransactions latest load date is already 2013-01-01 00:00:00.
# Upsert Data sql:
#                 -- Delete Records
# DELETE
# 	`dbt-tutorial-462014.WideWorldImporters2.Application_Cities`
# WHERE
# 	LoadDate > '2013-01-01 00:00:00';
#
# -- Drop Columns if existing
# ALTER TABLE `dbt-tutorial-462014.WideWorldImporters2.Application_Cities`
# DROP COLUMN IF EXISTS NewColumn;
#
# {'Successfully rolled back table Application_Cities to 2013-01-01 00:00:00.'}
# Upsert Data sql:
#                 -- Delete Records
# DELETE
# 	`dbt-tutorial-462014.WideWorldImporters2.Application_Cities_Archive`
# WHERE
# 	LoadDate > '2013-01-01 00:00:00';
#
# -- Drop Columns if existing
# ALTER TABLE `dbt-tutorial-462014.WideWorldImporters2.Application_Cities_Archive`
# DROP COLUMN IF EXISTS NewColumn;
#
# {'Successfully rolled back table Application_Cities_Archive to 2013-01-01 00:00:00.'}
# {'Successfully rolled back Load History Date'}
